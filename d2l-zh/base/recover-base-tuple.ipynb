# %%
# 元组（Tuple）
# 特性：不可变，是序列
# 元组用圆括号定义（圆括号可省略），元素没有类型限制
# 空元组
tup = ()
# 元组中只有一个元素时, 逗号不能省略
tup = (789,)
print(tup)
# 这不是元组，仍为数字789
tup = (789)
print(tup)
# 封包
tup = 'China', 1997, 2000
print(tup)
print(type(tup))
tup = ('China', 1997, 2000)
print(tup)
print(type(tup))
# Out:
# (789,)
# 789
# ('China', 1997, 2000)
# <class 'tuple'>
# ('China', 1997, 2000)
# <class 'tuple'>

# %%
# 元组是不可变的, 但其中的可变成员仍然可以被改变
# 元组存储的是引用（地址），不是实际对象
tup = (456, 'hello', ([789, 'world'],))
tup[-1][0][0] = 987
print(tup)
tup = (111,)
print(tup)
# Out:
# (456, 'hello', ([987, 'world'],))
# (111,)

# %%
# 元组是不可变的
my_tuple = (1, 2, 3)
print("原元组:", my_tuple)  # (1, 2, 3)

# ❌ 不能修改元素
try:
    my_tuple[0] = 10  # 报错！
except TypeError as e:
    print("错误:", e)  # 'tuple' object does not support item assignment

# ❌ 不能添加元素
try:
    my_tuple.append(4)  # 报错！元组没有append方法
except AttributeError as e:
    print("错误:", e)

# ❌ 不能删除元素
try:
    del my_tuple[1]  # 报错！
except TypeError as e:
    print("错误:", e)
# Out:
# 原元组: (1, 2, 3)
# 错误: 'tuple' object does not support item assignment
# 错误: 'tuple' object has no attribute 'append'
# 错误: 'tuple' object doesn't support item deletion

# %%
# tuple([iterable])
# 将一个iterable对象转化为元组并返回，如果没有实参，则
# 返回空元组
print(tuple())
print(tuple("hello"))
print(tuple([1, 2, 3]))
# 字典作为一个iterable, 只有键参与迭代
print(tuple({1: 2, 3: 4}))
print(tuple({'a', 'b', 'c', 789, 456}))
# Out:
# ()
# ('h', 'e', 'l', 'l', 'o')
# (1, 2, 3)
# (1, 3)
# ('a', 'c', 'b', 789, 456)

# %%
# 元组方法
# tuple.count(x)
# 返回元素 x 在元组中出现的次数
tup = (1, 2, 3, 2, '23', [2, 4])
print(tup.count(2))
